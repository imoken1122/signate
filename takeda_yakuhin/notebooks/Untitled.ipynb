# %%
kbest =['col5', 'col10', 'col15', 'col22', 'col29', 'col38', 'col46',
       'col48', 'col56', 'col68', 'col71', 'col87', 'col99', 'col104',
       'col107', 'col113', 'col115', 'col118', 'col119', 'col121',
       'col124', 'col130', 'col134', 'col168', 'col176', 'col182',
       'col208', 'col209', 'col218', 'col226', 'col232', 'col237',
       'col240', 'col248', 'col253', 'col255', 'col256', 'col269',
       'col281', 'col305', 'col306', 'col312', 'col329', 'col340',
       'col342', 'col352', 'col357', 'col359', 'col381', 'col413',
       'col420', 'col441', 'col453', 'col454', 'col514', 'col524',
       'col525', 'col533', 'col552', 'col554', 'col567', 'col571',
       'col590', 'col598', 'col620', 'col624', 'col654', 'col670',
       'col679', 'col690', 'col699', 'col723', 'col730', 'col744',
       'col766', 'col767', 'col768', 'col775', 'col791', 'col803',
       'col816', 'col820', 'col900', 'col965', 'col1008', 'col1032',
       'col1038', 'col1050', 'col1071', 'col1118', 'col1139', 'col1174',
       'col1242', 'col1252', 'col1273', 'col1279', 'col1292', 'col1315',
       'col1318', 'col1323', 'col1337', 'col1382', 'col1532', 'col1535',
       'col1540', 'col1545', 'col1555', 'col1557', 'col1563', 'col1587',
       'col1601', 'col1632', 'col1669', 'col1687', 'col1698', 'col1731',
       'col1768', 'col1770', 'col1796', 'col1815', 'col1844', 'col1855',
       'col1873', 'col1938', 'col1960', 'col2074', 'col2077', 'col2101',
       'col2147', 'col2219', 'col2236', 'col2306', 'col2365', 'col2391',
       'col2413', 'col2431', 'col2439', 'col2518', 'col2537', 'col2560',
       'col2614', 'col2616', 'col2621', 'col2669', 'col2699', 'col2722',
       'col2744', 'col2789', 'col2834', 'col2867', 'col2885', 'col2888',
       'col2902', 'col2914', 'col2921', 'col2925', 'col2963', 'col2989',
       'col3051', 'col3058', 'col3139', 'col3194', 'col3275', 'col3277',
       'col3300', 'col3353', 'col3379', 'col3431', 'col3472', 'col3477',
       'col3521', 'col3531', 'col3552', 'col3590', 'col3642', 'col3653',
       'col3661', 'col3698', 'col3699', 'col3711', 'col3725', 'col70',
       'col88', 'col142', 'col153', 'col161', 'col162', 'col195',
       'col286', 'col458', 'col463', 'col537', 'col569', 'col588',
       'col635', 'col680', 'col746', 'col753', 'col777', 'col793',
       'col821', 'col879', 'col887', 'col925', 'col975', 'col986',
       'col1006', 'col1039', 'col1040', 'col1053', 'col1095', 'col1096',
       'col1138', 'col1170', 'col1184', 'col1185', 'col1195', 'col1223',
       'col1229', 'col1232', 'col1235', 'col1287', 'col1329', 'col1444',
       'col1447', 'col1459', 'col1517', 'col1541', 'col1704', 'col1725',
       'col1741', 'col1857', 'col1862', 'col1991', 'col2062', 'col2117',
       'col2143', 'col2180', 'col2185', 'col2230', 'col2241', 'col2258',
       'col2261', 'col2275', 'col2349', 'col2360', 'col2387', 'col2399',
       'col2410', 'col2414', 'col2433', 'col2486', 'col2514', 'col2565',
       'col2584', 'col2677', 'col2693', 'col2818', 'col2845', 'col2981',
       'col2992', 'col2998', 'col3023', 'col3075', 'col3094', 'col3203',
       'col3215', 'col3312', 'col3330', 'col3331', 'col3364', 'col3372',
       'col3423', 'col3529', 'col3535', 'col3540', 'col3607', 'col3640',
       'col3684', 'col3723', 'col3727', 'col3741', 'col3751', 'col3769',
       'col3775', 'col3797', 'col3805', 'col9', 'col35', 'col117',
       'col146', 'col147', 'col166', 'col193', 'col225', 'col244',
       'col277', 'col363', 'col384', 'col388', 'col395', 'col408',
       'col438', 'col459', 'col473', 'col485', 'col486', 'col498',
       'col500', 'col510', 'col540', 'col557', 'col579', 'col596',
       'col609', 'col633', 'col638', 'col745', 'col750', 'col751',
       'col763', 'col801', 'col805', 'col826', 'col850', 'col924',
       'col928', 'col950', 'col985', 'col990', 'col1015', 'col1019',
       'col1027', 'col1074', 'col1087', 'col1132', 'col1135', 'col1143',
       'col1160', 'col1167', 'col1182', 'col1193', 'col1231', 'col1254',
       'col1278', 'col1288', 'col1317', 'col1343', 'col1359', 'col1376',
       'col1401', 'col1413', 'col1414', 'col1417', 'col1424', 'col1430',
       'col1450', 'col1453', 'col1458', 'col1488', 'col1489', 'col1491',
       'col1506', 'col1509', 'col1526', 'col1566', 'col1575', 'col1605',
       'col1610', 'col1621', 'col1633', 'col1693', 'col1710', 'col1711',
       'col1717', 'col1733', 'col1738', 'col1767', 'col1780', 'col1787',
       'col1816', 'col1864', 'col1883', 'col1894', 'col1918', 'col1931',
       'col1944', 'col1964', 'col1975', 'col1976', 'col2003', 'col2024',
       'col2081', 'col2092', 'col2111', 'col2116', 'col2120', 'col2132',
       'col2135', 'col2138', 'col2150', 'col2204', 'col2225', 'col2228',
       'col2304', 'col2335', 'col2336', 'col2369', 'col2372', 'col2393',
       'col2395', 'col2402', 'col2405', 'col2446', 'col2460', 'col2463',
       'col2475', 'col2494', 'col2533', 'col2579', 'col2607', 'col2609',
       'col2617', 'col2630', 'col2639', 'col2663', 'col2680', 'col2724',
       'col2752', 'col2769', 'col2836', 'col2853', 'col2865', 'col2873',
       'col2894', 'col2895', 'col2936', 'col2937', 'col2939', 'col2964',
       'col2973', 'col2977', 'col3005', 'col3056', 'col3065', 'col3097',
       'col3110', 'col3114', 'col3117', 'col3183', 'col3185', 'col3199',
       'col3213', 'col3248', 'col3268', 'col3289', 'col3290', 'col3291',
       'col3308', 'col3310', 'col3340', 'col3349', 'col3358', 'col3405',
       'col3433', 'col3434', 'col3466', 'col3469', 'col3498', 'col3519',
       'col3543', 'col3548', 'col3560', 'col3591', 'col3619', 'col3626',
       'col3637', 'col3639', 'col3683', 'col3689', 'col3696', 'col3716',
       'col3736', 'col3743', 'col3754', 'col3768']
import json
import numpy as np
with open('../configs/Kbest_FE.json') as f:
    df = json.load(f)
fl_score = np.array(df["FE_score"]["float_score"])
int_score = np.array(df["FE_score"]["int_score"])
cate_score = np.array(df["FE_score"]["cate_score"])
fl_fe = df["kbest_feature"]["float"]
int_fe = df["kbest_feature"]["int"]
cate_fe = df["kbest_feature"]["cate"]

# %%
import pandas as pd
import numpy as np
import feather
train = feather.read_dataframe("../data/input/tr_best.feather")
test = feather.read_dataframe("../data/input/te_best.feather")

# %%
del train["index"],test["index"],test["ID"],train["Score"]

# %%
score = train["Score"]
ID = test["ID"]

# %%
tr,te = train,test

# %%
int_c = tr.columns[tr.dtypes == int]
int_data = tr[int_c].append(te[int_c])
cate_c = []
for i in int_data.columns:
    a = int_data[i].value_counts().keys().values
    aa = np.arange(min(a),max(a) + 1)
    if len(set(a)) == len(aa):
        cate_c.append(i)

# %%
fl_data = tr.drop(int_c,axis = 1).append(te.drop(int_c,axis = 1))
cate_data = int_data[cate_c]
int_data = int_data.drop(cate_c,axis = 1)

# %%
fl_tr = fl_data.iloc[:13731,:]
fl_te = fl_data.iloc[13731:,:]

# %%
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import SelectKBest, SelectPercentile
import feather


MI = mutual_info_regression(fl_tr,score)
MI = pd.Series(MI)
MI.index = fl_tr.columns
MI.sort_values(ascending=False).plot(kind='bar', figsize=(20,10))
# Out:
# /usr/local/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
MI.sort_values(ascending=False).plot(kind='bar', figsize=(20,10))
# Out:
# /usr/local/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
kbest_sel_ = SelectKBest(mutual_info_regression, k=180)
kbest_sel_.fit(fl_tr,score)
# Out:
# 200
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fl_kbest_c = fl_data.columns[fl_score.scores!=0].values

# %%
int_tr = int_data.iloc[:13731,:]
int_te = int_data.iloc[13731:,:]

# %%
MI = mutual_info_regression(int_tr,score)
MI = pd.Series(MI)
MI.index = int_tr.columns
MI.sort_values(ascending=False).plot(kind='bar', figsize=(20,10))
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# /usr/local/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
kbest_sel_int = SelectKBest(mutual_info_regression, k=138)
kbest_sel_int.fit(int_tr,score)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# SelectKBest(k=138,
#       score_func=<function mutual_info_regression at 0x165b60d90>)

# %%
int_data.columns[kbest_sel_int.scores_>0.0015]
# Out:
# Index(['col4', 'col70', 'col88', 'col95', 'col142', 'col144', 'col153',
#        'col161', 'col162', 'col195',
#        ...
#        'col3684', 'col3723', 'col3727', 'col3741', 'col3751', 'col3769',
#        'col3775', 'col3788', 'col3797', 'col3805'],
#       dtype='object', length=136)

# %%
int_kbest_c = int_data.columns[kbest_sel_int.scores_>0.001].values

# %%
cate_tr = cate_data.iloc[:13731,:]
cate_te = cate_data.iloc[13731:,:]
MI = mutual_info_regression(cate_tr,score)
MI = pd.Series(MI)
MI.index = cate_tr.columns
MI.sort_values(ascending=False).plot(kind='bar', figsize=(20,10))
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# /usr/local/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
kbest_sel_cate = SelectKBest(mutual_info_regression, k=200)
kbest_sel_cate.fit(cate_tr,score)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)

# %%
fl_kbest_c = fl_data.columns[fl_score > 0.0023]
int_kbest_c = int_data.columns[int_score > 0.005]
cate_kbest_c = cate_data.columns[cate_score > 0.0025]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-4a60c55e219b> in <module>()
# ----> 1 fl_kbest_c = fl_data.columns[fl_score > 0.0023]
#       2 int_kbest_c = int_data.columns[int_score > 0.005]
#       3 cate_kbest_c = cate_data.columns[cate_score > 0.0025]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    2093
#    2094         key = com._values_from_object(key)
# -> 2095         result = getitem(key)
#    2096         if not is_scalar(result):
#    2097             return promote(result)
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 484 but corresponding boolean dimension is 200

# %%
fl_kbest_c = fl_data.columns[fl_score > 0.005]
int_kbest_c = int_data.columns[int_score > 0.005]
cate_kbest_c = cate_data.columns[cate_score > 0.003]

# %%
def df_concat(flist):
    add_columns = flist[0].columns.values.tolist()
    add_df = flist[0].values
    for i in flist[1:]:
        add_columns += i.columns.values.tolist()
        add_df = np.c_[add_df,i.values]
    return pd.DataFrame(add_df,columns=add_columns)

# %%
cate_best = cate_data[cate_kbest_c]
fl_best = fl_data[fl_kbest_c]
int_best = int_data[int_kbest_c]
data = df_concat([fl_best,int_best,cate_best])

# %%
all_feature = data.columns.values

# %%
cate_kbest_c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b29dcb8d6152> in <module>()
# ----> 1 cate_kbest_c
#
# NameError: name 'cate_kbest_c' is not defined

# %%
#data = df_concat([fl_best,int_best,cate_best])
tr,te= data.iloc[:13731,:],data.iloc[13731:,:]
tr["Score"] = score
te["ID"] = ID.values
tr = tr.reset_index()
te = te.reset_index()
tr.to_feather("../data/input/tr_best.feather")
te.to_feather("../data/input/te_best.feather")
import json
ff = tr.columns.values.tolist()[:-1]
features = {"features":ff, "target_name":"Score"}

with open("../configs/config_kbest.json","w") as f:
    json.dump(features,f)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
sum(train["Score"]> 4.5)
# Out:
# 26

# %%
feedsjson = open("../configs/FE_Kbest_score.json",'r')
feeds = json.load(feedsjson)
entry = {
        "kbest_feature":{
                    "all":all_feature.tolist(),
                     "float":fl_kbest_c.values.tolist(),
                    "int":int_kbest_c.values.tolist(),
                     "cate": cate_kbest_c.values.tolist()
        }}
feedsjson = open("../configs/Kbest_FE.json",'a')

json.dump(feeds, feedsjson)
json.dump(entry, feedsjson)

# %%
feedsjson = open("../configs/Kbest_FE.json",'r')
feeds = json.load(feedsjson)

# %%
## float
from tqdm import tqdm
def interact_encoding(data,f):
    new = pd.DataFrame()
    for i in tqdm(range(len(f))):
        for j in range(i):
            c,cc = f[i],f[j]
            new["add_" + c +"_"+ cc ] = data[c].values + data[cc].values
            new["minus_" + c +"_"+ cc ] = data[c].values- data[cc].values
            new["dot_" + c +"_"+ cc ] = data[c].values*data[cc].values
    return new


def best_importance_col(data,f):
    new = pd.DataFrame()
    imp_c = f[0]
    for c in tqdm(f[1:]):
        new["add_" + imp_c +"_"+ c ] = data[imp_c]+ data[c]
        new["minus_" + imp_c +"_"+ c ] = data[imp_c]- data[c]
        new["dot_" + imp_c +"_"+ c ] = data[imp_c]*data[c]
    return new

def float_stats(data):
    
    new = pd.DataFrame()
    c = data.columns

    new["mean_float"] = data[c].mean(axis = 1)
    new["var_float"] = data[c].var(axis = 1)
    new["std_float"] = data[c].std(axis = 1)
    new["max_float"] = data[c].max(axis = 1)
    new["min_float"] = data[c].min(axis = 1)
    new["kurtosis_float"] = data[c].kurtosis(axis =1)
    new["skew_float"] = data[c].skew(axis= 1)
    return new
def add_ZeroAgg(data):
    flist = [x for x in data.columns if not x in ['ID','target']]
    new = pd.DataFrame()
    new['sum_Zeros'] = (data[flist] == 0).astype(int).sum(axis=1)
    new['mean_Zeros'] = (data[flist] == 0).astype(int).mean(axis=1)
    new['median_Zeros'] = (data[flist] == 0).astype(int).median(axis=1)
    new['max_Zeros'] = (data[flist] == 0).astype(int).max(axis=1)
    new['min_Zeros'] = (data[flist] == 0).astype(int).min(axis=1)
    new['std_Zeros'] = (data[flist] == 0).astype(int).std(axis=1)
    new['var_Zeros'] = (data[flist] == 0).astype(int).var(axis=1)
    new['skew_Zeros'] = (data[flist] == 0).astype(int).skew(axis=1)
    new['kurtosis_Zeros'] = (data[flist] == 0).astype(int).kurtosis(axis=1)
    return new


def add_NegAgg(data):
    flist = [x for x in data.columns if not x in ['ID','target']]
    new = pd.DataFrame()
    new['sum_Neg'] = (data[flist] < 0).astype(int).sum(axis=1)
    new['median_Neg'] = (data[flist] < 0).astype(int).median(axis=1)
    new['mean_Neg'] = (data[flist] < 0).astype(int).mean(axis=1)
    new['std_Neg'] = (data[flist] < 0).astype(int).std(axis=1)
    new['var_Neg'] = (data[flist] < 0).astype(int).var(axis=1)
    new['max_Neg'] = (data[flist] < 0).astype(int).min(axis=1)
    new['min_Neg'] = (data[flist]< 0).astype(int).max(axis=1)
    new['skew_Neg'] = (data[flist] < 0).astype(int).skew(axis=1)
    new['kurtosis_Neg'] = (data[flist] < 0).astype(int).kurtosis(axis=1)
    return new



def add_IncAgg(data):
    flist = [x for x in data.columns if not x in ['ID','target']]
    new = pd.DataFrame()
    new['sum_Inc'] = (data[flist] > 0).astype(int).sum(axis=1)
    new['mean_Inc'] = (data[flist] > 0).astype(int).mean(axis=1)
    new['median_Inc'] = (data[flist] > 0).astype(int).median(axis=1)
    new['std_Inc'] = (data[flist] > 0).astype(int).std(axis=1)
    new['var_Inc'] = (data[flist] > 0).astype(int).var(axis=1)
    new['min_Inc'] = (data[flist] > 0).astype(int).min(axis=1)
    new['max_Inc'] = (data[flist] > 0).astype(int).max(axis=1)
    new['skew_Inc'] = (data[flist] > 0).astype(int).skew(axis=1)
    new['kurtosis_Inc'] = (data[flist] > 0).astype(int).kurtosis(axis=1)
    return new


def add_UniqAgg(data):

    new = pd.DataFrame()
    for i in tqdm(range(len(data))):
        new.loc[i,'sum_Uniq'] = np.unique(data.iloc[i,:]).sum()
        new.loc[i,'mean_Uniq'] = np.unique(data.iloc[i,:]).mean()
        new.loc[i,'std_Uniq'] = np.unique(data.iloc[i,:]).std()
        new.loc[i,'var_Uniq'] =  np.unique(data.iloc[i,:]).var()
        new.loc[i,'min_Uniq'] =  np.unique(data.iloc[i,:]).max()
        new.loc[i,'max_Uniq'] =  np.unique(data.iloc[i,:]).min()
        new.loc[i,'skew_Uniq'] = pd.DataFrame(data.iloc[i,:].unique()).skew().values
        new.loc[i,'kurtosis_Uniq'] = pd.DataFrame(data.iloc[i,:].unique()).kurtosis().values
    return new


fl_score = np.array(fl_score)
#f = fl_data.columns[kbest_sel_.scores_ > 0.037].values
f = fl_data.columns[fl_score > 0.025]
#ff = fl_data.columns[(fl_score<0.007) & (kbest_sel_.scores_ != 0)].values
#f = np.r_[f,ff]
data = fl_data
#FE1_f = interact_encoding(data,f)
#FE2_f = best_importance_col(data,f)
#FE3_f = float_stats(data)
#FE4_f = add_UniqAgg(data)
#FE5_f = add_IncAgg(data)
#FE6_f = add_ZeroAgg(data)
FE7_f = add_NegAgg(data)
FE_f = df_concat([FE1_f,FE2_f,FE3_f,FE4_f,FE5_f,FE6_f,FE7_f])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-300-36e17b0dc7f5> in <module>()
# ----> 1 np.skew()
#
# AttributeError: module 'numpy' has no attribute 'skew'

# %%
#int 
def int_stats(data):
    
    new = pd.DataFrame()
    c = data.columns

    new["mean_int"] = data[c].mean(axis = 1)
    new["var_int"] = data[c].var(axis = 1)
    new["std_int"] = data[c].std(axis = 1)
    new["max_int"] = data[c].max(axis = 1)
    new["min_int"] = data[c].min(axis = 1)
    new["kurtosis_int"] = data[c].kurtosis(axis =1)
    new["skew_int"] = data[c].skew(axis= 1)
    return new

def add_ZeroAgg(data):
    flist = [x for x in data.columns if not x in ['ID','target']]
    new = pd.DataFrame()
    new['sum_Zeros'] = (data[flist] == 0).astype(int).sum(axis=1)
    new['mean_Zeros'] = (data[flist] == 0).astype(int).mean(axis=1)
    new['median_Zeros'] = (data[flist] == 0).astype(int).median(axis=1)
    new['max_Zeros'] = (data[flist] == 0).astype(int).max(axis=1)
    new['min_Zeros'] = (data[flist] == 0).astype(int).min(axis=1)
    new['std_Zeros'] = (data[flist] == 0).astype(int).std(axis=1)
    new['var_Zeros'] = (data[flist] == 0).astype(int).var(axis=1)
    new['skew_Zeros'] = (data[flist] == 0).astype(int).skew(axis=1)
    new['kurtosis_Zeros'] = (data[flist] == 0).astype(int).kurtosis(axis=1)
    return new
def add_NegAgg(data):
    flist = [x for x in data.columns if not x in ['ID','target']]
    new = pd.DataFrame()
    new['sum_Neg'] = (data[flist] < 0).astype(int).sum(axis=1)
    new['median_Neg'] = (data[flist] < 0).astype(int).median(axis=1)
    new['mean_Neg'] = (data[flist] < 0).astype(int).mean(axis=1)
    new['std_Neg'] = (data[flist] < 0).astype(int).std(axis=1)
    new['var_Neg'] = (data[flist] < 0).astype(int).var(axis=1)
    new['max_Neg'] = (data[flist] < 0).astype(int).min(axis=1)
    new['min_Neg'] = (data[flist]< 0).astype(int).max(axis=1)
    new['skew_Neg'] = (data[flist] < 0).astype(int).skew(axis=1)
    new['kurtosis_Neg'] = (data[flist] < 0).astype(int).kurtosis(axis=1)
    return new



def add_IncAgg(data):
    flist = [x for x in data.columns if not x in ['ID','target']]
    new = pd.DataFrame()
    new['sum_Inc'] = (data[flist] > 0).astype(int).sum(axis=1)
    new['mean_Inc'] = (data[flist] > 0).astype(int).mean(axis=1)
    new['median_Inc'] = (data[flist] > 0).astype(int).median(axis=1)
    new['std_Inc'] = (data[flist] > 0).astype(int).std(axis=1)
    new['var_Inc'] = (data[flist] > 0).astype(int).var(axis=1)
    new['min_Inc'] = (data[flist] > 0).astype(int).min(axis=1)
    new['max_Inc'] = (data[flist] > 0).astype(int).max(axis=1)
    new['skew_Inc'] = (data[flist] > 0).astype(int).skew(axis=1)
    new['kurtosis_Inc'] = (data[flist] > 0).astype(int).kurtosis(axis=1)
    return new


def add_UniqAgg(data):

    new = pd.DataFrame()
    for i in tqdm(range(len(data))):
        new.loc[i,'sum_Uniq'] = np.unique(data.iloc[i,:]).sum()
        new.loc[i,'mean_Uniq'] = np.unique(data.iloc[i,:]).mean()
        new.loc[i,'std_Uniq'] = np.unique(data.iloc[i,:]).std()
        new.loc[i,'var_Uniq'] =  np.unique(data.iloc[i,:]).var()
        new.loc[i,'min_Uniq'] =  np.unique(data.iloc[i,:]).max()
        new.loc[i,'max_Uniq'] =  np.unique(data.iloc[i,:]).min()
        new.loc[i,'skew_Uniq'] = pd.DataFrame(data.iloc[i,:].unique()).skew().values
        new.loc[i,'kurtosis_Uniq'] = pd.DataFrame(data.iloc[i,:].unique()).kurtosis().values
    return new

def interact_encoding(data,f):
    new = pd.DataFrame()
    for i in tqdm(range(len(f))):
        for j in range(i):
            c,cc = f[i],f[j]
            new["add_" + c +"_"+ cc ] = data[c].values + data[cc].values
            new["minus_" + c +"_"+ cc ] = data[c].values- data[cc].values
            new["dot_" + c +"_"+ cc ] = data[c].values*data[cc].values
    return new


def best_importance_col(data,f):
    new = pd.DataFrame()
    imp_c = f[0]
    for c in tqdm(f[1:]):
        new["add_" + imp_c +"_"+ c ] = data[imp_c]+ data[c]
        new["minus_" + imp_c +"_"+ c ] = data[imp_c]- data[c]
        new["dot_" + imp_c +"_"+ c ] = data[imp_c]*data[c]
    return new
int_score = np.array(int_score)
f = int_data.columns[int_score >0.01]
#ff = int_data.columns[(kbest_sel_int.scores_<0.005) & (kbest_sel_int.scores_ != 0)].values
#f = np.r_[f,ff]
data = int_data
FE1_i = interact_encoding(data,f)
FE2_i = best_importance_col(data,f)
FE3_i = add_UniqAgg(data)
FE4_i = add_ZeroAgg(data)
FE5_i = add_NegAgg(data)
FE6_i = add_IncAgg(data)
FE7_i = int_stats(data)
FE_i = df_concat([FE1_i,FE2_i,FE3_i,FE4_i,FE5_i,FE6_i,FE7_i])
# Out:
# ...
# 100%|██████████| 48/48 [00:29<00:00,  1.81s/it]
#
# ...
#  45%|████▌     | 12440/27463 [01:35<01:57, 127.36it/s]
# ...
# ...
# 100%|██████████| 27463/27463 [03:41<00:00, 124.00it/s]

# %%
#category
from sklearn import base
from sklearn.model_selection import KFold
class KFoldTargetEncoderTrain(base.BaseEstimator, base.TransformerMixin):

    def __init__(self, colnames,targetName,n_fold=3,k =5,verbosity=True,discardOriginal_col=False):

        self.colnames = colnames
        self.targetName = targetName
        self.n_fold = n_fold
        self.verbosity = verbosity
        self.discardOriginal_col = discardOriginal_col
        self.k = k
    def fit(self, X, y=None):
        return self
    def transform(self,X):

        assert(type(self.targetName) == str)
        assert(type(self.colnames) == str)
        assert(self.colnames in X.columns)
        assert(self.targetName in X.columns)

        mean_of_target = X[self.targetName].mean()
        target = X[self.targetName]
        kf = KFold(n_splits = self.n_fold, shuffle = False, random_state=1103)
        col_mean_name = self.colnames + '_' + 'Kfold_Target_Enc'
        X[col_mean_name] = np.nan

        for tr_ind, val_ind in kf.split(X):
            X_tr, X_val = X.iloc[tr_ind], X.iloc[val_ind]
#             print(tr_ind,val_ind)
        #X.loc[X.index[val_ind], col_mean_name] = X_val[self.colnames].map(X_tr.groupby(self.colnames)[self.targetName].mean())
            X.loc[X.index[val_ind], col_mean_name] = X_val[self.colnames].map(self.fit_smoothing(X_tr, self.colnames))
        X[col_mean_name].fillna(mean_of_target, inplace = True)

        if self.verbosity:
            encoded_feature = X[col_mean_name].values
            print('Correlation between the new feature, {} and, {} is {}.'.format(col_mean_name,
                                                                                      self.targetName,
                                                                                      np.corrcoef(X[self.targetName].values, encoded_feature)[0][1]))
        if self.discardOriginal_col:
            X = X.drop(self.targetName, axis=1)
            
        return X[col_mean_name]
    def fit_smoothing(self,df,col):
        """
        一つの変数に対するTarget_Encoding
        col : TargetEncodingしたい変数名
        """

        k = self.k
        n_i = df.groupby(col).count()[self.targetName]

        lambda_n_i = self.sigmoid(n_i, k)
        uni_map = df.groupby(col).mean()[self.targetName]

        return lambda_n_i * df.loc[:, self.targetName].mean() + (1 - lambda_n_i) * uni_map
    
    def sigmoid(self, x, k):
        return 1 / (1 + np.exp(- x / k))

class KFoldTargetEncoderTest(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self,train,colNames,encodedName):
        
        self.train = train
        self.colNames = colNames
        self.encodedName = encodedName
        
    def fit(self, X, y=None):
        return self
    def transform(self,X):
        mean =  self.train[[self.colNames,
                self.encodedName]].groupby(
                                self.colNames).mean().reset_index() 
        dd = {}
        for index, row in mean.iterrows():
            dd[row[self.colNames]] = row[self.encodedName]
        X[self.encodedName] = X[self.colNames]
        X = X.replace({self.encodedName: dd})
        return X[self.encodedName]
def polynominal_encoding(data,f):
    new = pd.DataFrame()
    for i in tqdm(range(len(f))):
        for j in range(i):            
            new[f"{f[i]}_{f[j]}_XOR"] = np.logical_xor(data[f[i]], data[f[j]])  

    return new


def count_encoding(data,f):
    new = pd.DataFrame()
    for c in tqdm(f):
        v_c = data[c].value_counts()
        new[c + "_count_enc"] = data[c].map(v_c)
    return new


def label_count_encording(data,f):
    new = pd.DataFrame()
    for c in tqdm(f):
        count_dict = data[c].value_counts()
        label_count_dict = count_dict.rank(ascending=False).astype(int)
        encoded = data[c].map(label_count_dict)
        new[c + '_labelcount_enc'] = encoded
    return new

def add_ZeroAgg(data,flist):

    new = pd.DataFrame()
    new['sum_Zeros'] = (data[flist] == 0).astype(int).sum(axis=1)
    new['mean_Zeros'] = (data[flist] == 0).astype(int).mean(axis=1)
    new['median_Zeros'] = (data[flist] == 0).astype(int).median(axis=1)
    new['max_Zeros'] = (data[flist] == 0).astype(int).max(axis=1)
    new['min_Zeros'] = (data[flist] == 0).astype(int).min(axis=1)
    new['std_Zeros'] = (data[flist] == 0).astype(int).std(axis=1)
    new['var_Zeros'] = (data[flist] == 0).astype(int).var(axis=1)
    new['skew_Zeros'] = (data[flist] == 0).astype(int).skew(axis=1)
    new['kurtosis_Zeros'] = (data[flist] == 0).astype(int).kurtosis(axis=1)
    return new
cate_score= np.array(cate_score)
a = cate_data.columns[cate_score > 0.0025]
f = [x for x in a if len(np.unique(cate_data[x])) != 2]
binaly = [x for x in a if len(np.unique(cate_data[x])) == 2]
data = cate_data
FE1_c = add_ZeroAgg(data,a)
FE2_c = count_encoding(data,a)
FE3_c  = polynominal_encoding(data,binaly)
FE4_c = label_count_encording(data,f)
FE_c = df_concat([FE1_c,FE2_c,FE3_c,FE4_c])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d8634df80d8c> in <module>()
#     119     new['kurtosis_Zeros'] = (data[flist] == 0).astype(int).kurtosis(axis=1)
#     120     return new
# --> 121 cate_score= np.array(cate_score)
#     122 a = cate_data.columns[cate_score > 0.0025]
#     123 f = [x for x in a if len(np.unique(cate_data[x])) != 2]
#
# NameError: name 'np' is not defined

# %%
#ALL
def all_stats(data):
    
    new = pd.DataFrame()
    c = data.columns
    new["sum_all"] = data[c].sum(axis = 1)
    new["mean_all"] = data[c].mean(axis = 1)
    new["var_all"] = data[c].var(axis = 1)
    new["std_all"] = data[c].std(axis = 1)
    new["max_all"] = data[c].max(axis = 1)
    new["min_all"] = data[c].min(axis = 1)
    new["kurtosis_all"] = data[c].kurtosis(axis =1)
    new["skew_all"] = data[c].skew(axis= 1)
    return new

def add_ZeroAgg(data,d_type):
    flist = [x for x in data.columns if not x in ['ID','target']]
    new = pd.DataFrame()
    new[f'{d_type}_sum_Zeros'] = (data[flist] == 0).astype(int).sum(axis=1)
    new[f'{d_type}_mean_Zeros'] = (data[flist] == 0).astype(int).mean(axis=1)
    new[f'{d_type}_median_Zeros'] = (data[flist] == 0).astype(int).median(axis=1)
    new[f'{d_type}_max_Zeros'] = (data[flist] == 0).astype(int).max(axis=1)
    new[f'{d_type}_min_Zeros'] = (data[flist] == 0).astype(int).min(axis=1)
    new[f'{d_type}_std_Zeros'] = (data[flist] == 0).astype(int).std(axis=1)
    new[f'{d_type}_var_Zeros'] = (data[flist] == 0).astype(int).var(axis=1)
    new[f'{d_type}_skew_Zeros'] = (data[flist] == 0).astype(int).skew(axis=1)
    new[f'{d_type}_kurtosis_Zeros'] = (data[flist] == 0).astype(int).kurtosis(axis=1)
    return new
def add_notZeroAgg(data,d_type):
    flist = [x for x in data.columns if not x in ['ID','target']]
    new = pd.DataFrame()
    new[f'{d_type}_sum_notZeros'] = (data[flist] != 0).astype(int).sum(axis=1)
    new[f'{d_type}_mean_notZeros'] = (data[flist] != 0).astype(int).mean(axis=1)
    new[f'{d_type}_median_notZeros'] = (data[flist] != 0).astype(int).median(axis=1)
    new[f'{d_type}_max_notZeros'] = (data[flist] != 0).astype(int).max(axis=1)
    new[f'{d_type}_min_notZeros'] = (data[flist] != 0).astype(int).min(axis=1)
    new[f'{d_type}_std_notZeros'] = (data[flist] != 0).astype(int).std(axis=1)
    new[f'{d_type}_var_notZeros'] = (data[flist] != 0).astype(int).var(axis=1)
    new[f'{d_type}_skew_notZeros'] = (data[flist] != 0).astype(int).skew(axis=1)
    new[f'{d_type}_kurtosis_notZeros'] = (data[flist] != 0).astype(int).kurtosis(axis=1)
    return new
def add_NegAgg(data,d_type):
    flist = [x for x in data.columns if not x in ['ID','target']]
    new = pd.DataFrame()
    new[f'{d_type}_sum_Neg'] = (data[flist] < 0).astype(int).sum(axis=1)
    new[f'{d_type}_median_Neg'] = (data[flist] < 0).astype(int).median(axis=1)
    new[f'{d_type}_mean_Neg'] = (data[flist] < 0).astype(int).mean(axis=1)
    new[f'{d_type}_std_Neg'] = (data[flist] < 0).astype(int).std(axis=1)
    new[f'{d_type}_var_Neg'] = (data[flist] < 0).astype(int).var(axis=1)
    new[f'{d_type}_max_Neg'] = (data[flist] < 0).astype(int).min(axis=1)
    new[f'{d_type}_min_Neg'] = (data[flist]< 0).astype(int).max(axis=1)
    new[f'{d_type}_skew_Neg'] = (data[flist] < 0).astype(int).skew(axis=1)
    new[f'{d_type}_kurtosis_Neg'] = (data[flist] < 0).astype(int).kurtosis(axis=1)
    return new



def add_IncAgg(data,d_type):
    flist = [x for x in data.columns if not x in ['ID','target']]
    new = pd.DataFrame()
    new[f'{d_type}_sum_Inc'] = (data[flist] > 0).astype(int).sum(axis=1)
    new[f'{d_type}_mean_Inc'] = (data[flist] > 0).astype(int).mean(axis=1)
    new[f'{d_type}_median_Inc'] = (data[flist] > 0).astype(int).median(axis=1)
    new[f'{d_type}_std_Inc'] = (data[flist] > 0).astype(int).std(axis=1)
    new[f'{d_type}_var_Inc'] = (data[flist] > 0).astype(int).var(axis=1)
    new[f'{d_type}_min_Inc'] = (data[flist] > 0).astype(int).min(axis=1)
    new[f'{d_type}_max_Inc'] = (data[flist] > 0).astype(int).max(axis=1)
    new[f'{d_type}_skew_Inc'] = (data[flist] > 0).astype(int).skew(axis=1)
    new[f'{d_type}_kurtosis_Inc'] = (data[flist] > 0).astype(int).kurtosis(axis=1)
    return new


def add_UniqAgg(data,d_type):

    new = pd.DataFrame()
    for i in tqdm(range(len(data))):
        new.loc[i,f'{d_type}_sum_Uniq'] = np.unique(data.iloc[i,:]).sum()
        new.loc[i,f'{d_type}_mean_Uniq'] = np.unique(data.iloc[i,:]).mean()
        new.loc[i,f'{d_type}_std_Uniq'] = np.unique(data.iloc[i,:]).std()
        new.loc[i,f'{d_type}_var_Uniq'] =  np.unique(data.iloc[i,:]).var()
        new.loc[i,f'{d_type}_min_Uniq'] =  np.unique(data.iloc[i,:]).max()
        new.loc[i,f'{d_type}_max_Uniq'] =  np.unique(data.iloc[i,:]).min()
        new.loc[i,f'{d_type}_skew_Uniq'] = pd.DataFrame(data.iloc[i,:].unique()).skew().values
        new.loc[i,f'{d_type}_kurtosis_Uniq'] = pd.DataFrame(data.iloc[i,:].unique()).kurtosis().values
    return new
tr = feather.read_dataframe("../data/input/tr_best.feather")
te = feather.read_dataframe("../data/input/te_best.feather")
del tr["index"],tr["Score"],te["ID"],te["index"]
data= tr.append(te)
FE1_a = add_UniqAgg(data,"all")
FE2_a = add_ZeroAgg(data,"all")
FE3_a = add_IncAgg(data,"all")
FE4_a = add_NegAgg(data,"all")
FE5_a = all_stats(data)
FE6_a = add_notZeroAgg(data,"all")

# %%
FE_a = df_concat([aaa,FE2_a,FE3_a,FE4_a,FE5_a,FE6_a])

# %%
add_FE = df_concat([FE_f,FE_i,FE_c])

# %%
FE_f.to_feather("../features/add_float.feather")
FE_i.to_feather("../features/add_int.feather")
FE_c.to_feather("../features/add_cate.feather")
FE_a.to_feather("../features/add_Alltype.feather")

# %%
FE_f = feather.read_dataframe("../features/add_float.feather")
FE_i = feather.read_dataframe("../features/add_int.feather")
FE_a = feather.read_dataframe("../features/add_Alltype.feather")

# %%
from tqdm import tqdm

def preprocess(data):
#分散＝０
    train1,test1= data.iloc[:13731,:],data.iloc[13731:,:]
    #ダブり
    aa = train1.columns
    duplicate_f = train1[aa].T[train1[aa].T.duplicated()].index.values
    train1.drop(duplicate_f,axis=1,inplace=True)
    test1.drop(duplicate_f,axis=1,inplace=True)

    #分散
    from sklearn.feature_selection import VarianceThreshold
    sel = VarianceThreshold(threshold=0.005)
    sel.fit(train1)
    f = train1.columns[sel.get_support()].values
    train1 = train1[f]
    test1 = test1[f]


    from scipy.stats import ks_2samp
    list_p_value =[]

    for i in tqdm(train1.columns):
        list_p_value.append(ks_2samp(test1[i] , train1[i])[1])

    Se = pd.Series(list_p_value, index = train1.columns).sort_values() 
    list_discarded = list(Se[Se < .1].index)
    train1.drop(list_discarded,axis=1,inplace=True)
    test1.drop(list_discarded,axis=1,inplace=True)

    constant = []
    for col in tqdm(train1.columns):

        if len(train1[col].unique()) == 1:
            constant.append(col)
    train1 = train1.drop(columns=constant,axis=1)
    test1 = test1.drop(columns=constant,axis=1)
    return train1.append(test1)

# %%
data = preprocess(data)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# ...
# 100%|██████████| 484/484 [00:00<00:00, 604.02it/s]

# %%
train = feather.read_dataframe("../data/input/train.feather")
test = feather.read_dataframe("../data/input/test.feather")
dumy = feather.read_dataframe("../data/input/tr_best.feather")
del dumy["index"],dumy["Score"],test["ID"],train["ID"],train["Score"]
origin = train.append(test)

# %%
int_stats = FE_i.loc[:,"sum_Uniq":]
fl_stats = FE_f.loc[:,"mean_float":]
cate_stats = FE_c.loc[:,"sum_Zeros":"kurtosis_Zeros"]

# %%
int_stats = pd.DataFrame(int_stats.values, columns=add_i)
fl_stats = pd.DataFrame(fl_stats.values,columns=add_f)
cate_stats = pd.DataFrame(cate_stats.values,columns = add_c)

# %%
add_i = [f"int_{x}" for x in int_stats.columns]
add_f = [f"fl_{x}" for x in fl_stats.columns]
add_c = [f"cate_{x}" for x in cate_stats.columns]

# %%
origin = origin[dumy.columns]
#origin.drop(a,axis = 1, inplace = True)

# %%
#FE_cc = train1.append(test1)
#FE_c = df_concat([FE1_c,FE2_c,FE3_c,FE4_c,FE5_c])
tr = feather.read_dataframe("../data/input/tr_best.feather")
te = feather.read_dataframe("../data/input/te_best.feather")
del tr["index"],tr["Score"],te["ID"],te["index"]
#data= tr.append(te)
#data = df_concat([origin,yy,pca_f,int_stats,fl_stats,cate_stats])
origin = tr.append(te)
data = df_concat([origin,pca_f])

tr,te= data.iloc[:13731,:],data.iloc[13731:,:]
tr["Score"] = score
te["ID"] = ID.values

tr = tr.reset_index()
te = te.reset_index()
tr.to_feather("../data/input/tr_best_pca_ifa.feather")
te.to_feather("../data/input/te_best_pca_ifa.feather")
import json
del tr["index"],tr["Score"]
ff = tr.columns.values.tolist()
features = {"features":ff, "target_name":"Score"}

with open("../configs/config_kbest_ifa.json","w") as f:
    json.dump(features,f)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
from sklearn.preprocessing import StandardScaler

num_data = df_concat([FE_f,FE_i,FE_a])
#num_data = df_concat([fl_data, FE_f,])
#num_data = df_concat([int_data, FE_i,])
#num_data = df_concat([cate_data, FE_c,FE10_c])

stdsc = StandardScaler()
tr,te =num_data.iloc[:13731,:],num_data.iloc[13731:,:]
tr_std= stdsc.fit_transform(tr)
# 訓練用データを基準にテストデータも標準化
te_std = stdsc.transform(te)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize

def PCA_feature(X_train,X_test):

    n_components = 20
    pca = PCA(n_components=n_components)
    x_train_projected = pca.fit_transform(X_train)
    x_test_projected = pca.transform(X_test)
    new1 = pd.DataFrame()
    new2 = pd.DataFrame()
    for npca in range(0, n_components):
        new1['n_PCA_'+str(npca+1)] = x_train_projected[:, npca]
        new2['n_PCA_'+str(npca+1)] = x_test_projected[:, npca]
    new = new1.append(new2)
    return new
pca_f = PCA_feature(tr_std,te_std)

# %%
plt.scatter(pca_f.iloc[:,0],pca_f.iloc[:,1])
# Out:
# /usr/local/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
pca = PCA(n_components=16)
pca.fit(tr_std)
import matplotlib.pyplot as plt
plt.bar([n for n in range(1, len(pca.explained_variance_ratio_)+1)], pca.explained_variance_ratio_)
pca.explained_variance_ratio_.sum()
# Out:
# 0.7766502838223038

# %%
from sklearn.cluster import KMeans
def clustering_feature(X_train,X_test):
    flist = [x for x in X_train.columns if not x in ['ID','Score']]
    stdsc = StandardScaler()
    X_train= stdsc.fit_transform(X_train)
    X_test = stdsc.transform(X_test)
    X_train = pd.DataFrame(X_train,columns=flist)
    X_test= pd.DataFrame(X_test,columns=flist)
    loss = []
    flist_kmeans = []
    for ncl in range(8,15):
        cls = KMeans(n_clusters=ncl)
        cls.fit_predict(X_train[flist].values)
        loss.append(cls.inertia_)
        X_train['kmeans_cluster_'+str(ncl)] = cls.predict(X_train[flist].values)
        X_test['kmeans_cluster_'+str(ncl)] = cls.predict(X_test[flist].values)
        flist_kmeans.append('kmeans_cluster_'+str(ncl))
    return X_train,X_test,loss
tr_pca,te_pca = yy.iloc[:13731,:],yy.iloc[13731:,:]

a,b,loss = clustering_feature(tr_pca,te_pca)

# %%
clust_pca = a.append(b)

# %%
plt.plot(loss)

# %%
plt.scatter(a.iloc[:,0],a.iloc[:,1],c = a["kmeans_cluster_14"])

# %%
import feather,numpy as np ,pandas as pd
tr = feather.read_dataframe("../data/input/tr_best.feather")
te = feather.read_dataframe("../data/input/te_best.feather")

# %%
data = tr.append(te)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
dd =df_concat([data,FE10_c])

# %%
tr,te = dd.iloc[:13731,:],dd.iloc[13731:,:]

# %%
cate_c = df["kbest_feature"]["cate"]

# %%
score = tr["Score"]

# %%
label = np.where((0.5<=score) & (score<=3.8),1,0)
tr["label"] = label

# %%
del tr["Score"],tr["index"],te["index"]

# %%
def train_target_encoding(data,int_c):
    new = pd.DataFrame()
    
    for i in tqdm(int_c):
        targetc = KFoldTargetEncoderTrain(i,"label",n_fold=3,k=100,verbosity=False)
        new[i+'_Kfold_Target_Enc'] = targetc.fit_transform(data)
    return new
def test_target_encoding(tr,te,int_c):
    new = pd.DataFrame()
    for i in tqdm(int_c):
        test_targetc = KFoldTargetEncoderTest(tr,i,i + '_Kfold_Target_Enc')
        new[i + '_Kfold_Target_Enc'] = test_targetc.fit_transform(te)
    return new
from tqdm import tqdm

#a = cate_data.columns[cate_score > 0.0125]
#tgt_c = [i for i in a if len(cate_data[i].unique()) > 10]
tgt_c = cate_c
tr_c = tr[cate_c]
tr_c["label"] = label
te_c = te[cate_c]
tr_tgenc_f = train_target_encoding(tr_c,tgt_c)
te_tgenc_f = test_target_encoding(tr_c,te_c,tgt_c)
FE10_c = tr_tgenc_f.append(te_tgenc_f)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
#
#   0%|          | 0/198 [00:00<?, ?it/s]/usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
a = cate_data.columns[cate_score > 0.0125]
tgt_c = [i for i in a if len(cate_data[i].unique())!= 2]

# %%
import feather
train = feather.read_dataframe("../data/input/tr_best_add.feather")
test = feather.read_dataframe("../data/input/te_best_add.feather")

# %%
import json
with open('../configs/FE_Kbest_score.json') as f:
    df = json.load(f)
cate_score = df["FE_score"]["cate_score"]

# %%
cate_score = df["FE_score"]["cate_score"]

# %%
tr_label = label

# %%
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import SelectKBest, SelectPercentile
import feather

tr,te = FE10_c.iloc[:13731,:],FE10_c.iloc[13731:,:]
MI = mutual_info_regression(tr,score)
MI = pd.Series(MI)
MI.index = tr.columns
MI.sort_values(ascending=False).plot(kind='bar', figsize=(20,10))
# Out:
# /usr/local/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
kbest_sel_int = SelectKBest(mutual_info_regression, k=138)
kbest_sel_int.fit(tr,score)
# Out:
# SelectKBest(k=138,
#       score_func=<function mutual_info_regression at 0x1797abc80>)

# %%
kbest_add_c = tr.columns[kbest_sel_int.scores_>0.01].values

# %%
FE_best_c = FE_c[kbest_add_c]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer

def tf(doc):
    vectorizer = CountVectorizer(token_pattern=u'(?u)\\b\\w+\\b')
    features = vectorizer.fit_transform(doc)
    terms = vectorizer.get_feature_names()
    return features, terms

def tfidf(docs):
    vectorizer = TfidfVectorizer(min_df=2345, max_df=2539, token_pattern=u'(?u)\\b\\w+\\b')
    features = vectorizer.fit_transform(docs)
    terms = vectorizer.get_feature_names()

    return features, terms

def reduction(x, dim=10):
    '''
    dimensionality reduction using LSA
    '''
    lsa = TruncatedSVD()
    x = lsa.fit_transform(x)
    x = Normalizer(copy=False).fit_transform(x)
    return x

# %%
a,b = tfidf(aa)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-437-452b36a65bbb> in <module>()
# ----> 1 a,b = tfidf(aa)
#
# <ipython-input-436-b6fd3dbece43> in tfidf(docs)
#      12 def tfidf(docs):
#      13     vectorizer = TfidfVectorizer(min_df=2345, max_df=2539, token_pattern=u'(?u)\\b\\w+\\b')
# ---> 14     features = vectorizer.fit_transform(docs)
#      15     terms = vectorizer.get_feature_names()
#      16
#
# /usr/local/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1379             Tf-idf-weighted document-term matrix.
#    1380         """
# -> 1381         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1382         self._tfidf.fit(X)
#    1383         # X is already a transformed view of raw_documents so
#
# ...

# %%
aa = [' '.join(str(list(map(int,x)))) for x in FE_best_c.values[:,:]]

# %%
# Out:
# 2345

# %%
from sklearn.model_selection import cross_val_score,KFold
from sklearn.metrics import r2_score
from sklearn.neural_network import MLPRegressor
tr = feather.read_dataframe("../data/input/tr_best.feather")
y = tr["Score"]

del tr["Score"],tr["index"]
tr = tr.values
y = y.values
stdsc = StandardScaler()
tr = stdsc.fit_transform(tr)
kf = KFold(n_splits =10,random_state=1103)
for i,(tr_idx,val_idx) in enumerate(kf.split(tr)):
    train,valid = (tr[tr_idx,:],y[tr_idx]), (tr[val_idx,:],y[val_idx])
    

    model = MLPRegressor(hidden_layer_sizes=(1024,1024,1024,),random_state=103,max_iter=500)
    model.fit(train[0],train[1])
    pred = model.predict(valid[0])
    print(r2_score(valid[1],pred))
# Out:
# 0.560038505669435
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# 0.5290687146681604
# -0.07696004732558959
# -4.0697319271676085
# -0.9680501718771328
# -0.9497533285911801
# -2.9171161416659586
# -0.7241806558734603
# -3.809716816196561
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-456-ecde75ac50a1> in <module>()
#      12 kf = KFold(n_splits =10,random_state=1103)
#      13 for i,(tr_idx,val_idx) in enumerate(kf.split(tr)):
# ---> 14     train,valid = (tr[tr_idx,:],y[tr_idx]), (tr[val_idx,:],y[val_idx])
#      15
#      16
#
# KeyboardInterrupt:

# %%
y.values
# Out:
# array([3.475628, 3.601332, 1.935003, ..., 4.008115, 0.255273, 2.321184])

# %%
t = pd.read_csv("../submit_3ensmble.csv",header = None)
tt = pd.read_csv("../submit_3_1ensmble.csv",header = None)
ttt = pd.read_csv("../0.6172_0.6168_ensm.csv",header = None)
s = pd.read_csv("../data/input/sample_submit.csv",header=None)

# %%
s.iloc[:,1] = 0.2*(ttt.iloc[:,1] * 0.2 + t.iloc[:,1] * 0.8) + tt.iloc[:,1] * 0.8

# %%
s.to_csv("../submit_3_2ensmble.csv",header = None,index = None)

# %%
from sklearn.model_selection import cross_val_score,KFold
kf = KFold(n_splits =10,random_state=13)
for i,(tr_idx,val_idx) in enumerate(kf.split(tr)):
    print(tr_idx,val_idx)
# Out:
# [ 1374  1375  1376 ... 13728 13729 13730] [   0    1    2 ... 1371 1372 1373]
# [    0     1     2 ... 13728 13729 13730] [1374 1375 1376 ... 2744 2745 2746]
# [    0     1     2 ... 13728 13729 13730] [2747 2748 2749 ... 4117 4118 4119]
# [    0     1     2 ... 13728 13729 13730] [4120 4121 4122 ... 5490 5491 5492]
# [    0     1     2 ... 13728 13729 13730] [5493 5494 5495 ... 6863 6864 6865]
# [    0     1     2 ... 13728 13729 13730] [6866 6867 6868 ... 8236 8237 8238]
# [    0     1     2 ... 13728 13729 13730] [8239 8240 8241 ... 9609 9610 9611]
# [    0     1     2 ... 13728 13729 13730] [ 9612  9613  9614 ... 10982 10983 10984]
# [    0     1     2 ... 13728 13729 13730] [10985 10986 10987 ... 12355 12356 12357]
# [    0     1     2 ... 12355 12356 12357] [12358 12359 12360 ... 13728 13729 13730]

# %%
t = feather.read_dataframe("../features/add_float.feather")
tt = feather.read_dataframe("../features/add_int.feather")

# %%
num_data = df_concat([t,tt])

# %%
import sklearn.base
from  bhtsne import tsne
import numpy as np



num_data = df_concat([FE_f,FE_i,FE_a])
del FE_f,FE_i,FE_a
stdsc = StandardScaler()
tr,te =num_data.iloc[:13731,:],num_data.iloc[13731:,:]
tr_std= stdsc.fit_transform(tr)
# 訓練用データを基準にテストデータも標準化
te_std = stdsc.transform(te)
num_data = np.r_[tr_std, te_std]
y = tsne(num_data,rand_seed=1103,dimensions=3,perplexity=35)

# %%
import matplotlib.pyplot as plt
plt.scatter(y[:,0],y[:,1],s = 0.2,marker = ".")

# %%
y.to_feather("../features/add_tSNE.feather")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-363-11f10f28e7d7> in <module>()
# ----> 1 y.to_feather("../features/add_tSNE.feather")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_feather'

# %%
t = feather.read_dataframe("../data/input/tr_best.feather")
tt = feather.read_dataframe("../data/input/te_best.feather")

# %%
del t["Score"],tt["ID"],t["index"],tt["index"]

# %%
yy = pd.DataFrame(y,columns=["tsne_1","tsne_2","tsne_3"])
data = t.append(tt)
sub = df_concat([data,yy])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-366-033c8715a0a1> in <module>()
#       1 yy = pd.DataFrame(y,columns=["tsne_1","tsne_2","tsne_3"])
#       2 data = t.append(tt)
# ----> 3 sub = df_concat([data,yy])
#
# <ipython-input-42-024c7734c9c3> in df_concat(flist)
#       4     for i in flist[1:]:
#       5         add_columns += i.columns.values.tolist()
# ----> 6         add_df = np.c_[add_df,i.values]
#       7     return pd.DataFrame(add_df,columns=add_columns)
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/index_tricks.py in __getitem__(self, key)
#     333                 objs[k] = objs[k].astype(final_dtype)
#     334
# --> 335         res = self.concatenate(tuple(objs), axis=axis)
#     336
#     337         if matrix:
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
tr,te = sub.iloc[:13731,:],sub.iloc[13731:,:]
tr["Score"] = score
te["ID"] = ID.values

tr = tr.reset_index()
te = te.reset_index()
tr.to_feather("../data/input/tr_best_tsne.feather")
te.to_feather("../data/input/te_best_tsne.feather")
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import json
del tr["index"],tr["Score"]
ff = tr.columns.values.tolist()
features = {"features":ff, "target_name":"Score"}

with open("../configs/config_kbest_tsne.json","w") as f:
    json.dump(features,f)

# %%
import numpy as np #適当な配列作るためにNumpy使う
X =y[:,0]
Y = y[:,1]
Z = y[:,2]
#備考：Numpyだとnp.log()は自然対数。常用対数はnp.log10()

import matplotlib.pyplot as plt

#seabornでグラフをきれいにしたいだけのコード
import seaborn as sns
sns.set_style("darkgrid")

#3次元プロットするためのモジュール
from mpl_toolkits.mplot3d import Axes3D

#グラフの枠を作っていく
fig = plt.figure()
ax = Axes3D(fig)

#軸にラベルを付けたいときは書く
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

#.plotで描画
#linestyle='None'にしないと初期値では線が引かれるが、3次元の散布図だと大抵ジャマになる
#markerは無難に丸
ax.plot(X,Y,Z,marker=".",linestyle='None',markersize = 0.2)

#最後に.show()を書いてグラフ表示
plt.show()

# %%
FE_cc = FE_c.loc[:,'col117_col35_XOR':]

# %%
countvec = df_concat([cate_data,FE_cc])

# %%
for c in countvec.columns:
    countvec[c] = np.round(np.log1p(countvec[c]),3)

# %%
tmp = countvec[countvec.columns[0]].apply(str)
tmp[ tmp=='0.0' ] = ''
CV = pd.DataFrame()
CV['features'] = tmp

for feat in countvec.columns[1:]:
    tmp = countvec[feat].apply(str)
    tmp[ tmp=='0.0' ] = ''
    CV['features'] = CV['features'] + tmp + ' '

# %%
CV.iloc[0]
# Out:
# features    2.485      1.386      0.693       1.386  0.693...
# Name: 0, dtype: object

# %%
countvec[countvec == 0.000] = "0.0"

# %%
from sklearn.feature_extraction.text import CountVectorizer
rd = CountVectorizer( lowercase=True, ngram_range=(1, 1), max_df=0.99, min_df=2)
tr = rd.fit_transform( CV['features'] )
del rd, CV

# %%
cv = pd.DataFrame(tr.toarray(),columns=[f"{i}_countvec" for i in range(tr.shape[1])])

# %%
trr = feather.read_dataframe("../data/input/tr_best.feather")

# %%
trr = feather.read_dataframe("../data/input/tr_best.feather")
te = feather.read_dataframe("../data/input/te_best.feather")
trr.drop(cate_c,axis = 1 , inplace = True)
te.drop(cate_c,axis = 1 , inplace = True)
del trr["index"],trr["Score"],te["ID"]
origin = trr.append(te)

data = df_concat([origin,cv])


tr,te= data.iloc[:13731,:],data.iloc[13731:,:]
tr["Score"] = score
te["ID"] = ID.values

tr = tr.reset_index()
te = te.reset_index()
tr.to_feather("../data/input/tr_best_cv.feather")
te.to_feather("../data/input/te_best_cv.feather")
import json
del tr["index"],tr["Score"]
ff = tr.columns.values.tolist()
features = {"features":ff, "target_name":"Score"}

with open("../configs/config_kbest_cv.json","w") as f:
    json.dump(features,f)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
tr = tr.reset_index()
te = te.reset_index()
tr.to_feather("../data/input/tr_best_tgt.feather")
te.to_feather("../data/input/te_best_tgt.feather")

# %%
import json
del tr["index"],tr["Score"]
ff = tr.columns.values.tolist()
features = {"features":ff, "target_name":"Score"}

with open("../configs/config_kbest_tgt.json","w") as f:
    json.dump(features,f)

# %%
np.array(int_fe)[int_score>0.01]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-d9a9751e0401> in <module>()
# ----> 1 np.array(int_fe)[int_score>0.01]
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 106 but corresponding boolean dimension is 158

# %%
del train["ID"]

# %%
int_data.columns[int_score>0.01]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-c4b66b4157ae> in <module>()
# ----> 1 int_data.columns[int_score>0.01]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    2093
#    2094         key = com._values_from_object(key)
# -> 2095         result = getitem(key)
#    2096         if not is_scalar(result):
#    2097             return promote(result)
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 106 but corresponding boolean dimension is 158

# %%
a = ["col88","col3372","col2414","col2349","col1725","col1287","col2410","col142","col1235","col1232","col1039",                                               
"col887","col3640","col2845","col1459","col286","col1053","col2565","col1006","col3535","col1195","col2433","col1195","col2433","col1704","col161","col777"
      ,"col2062","col793","col2387","col2241","col1991","col3751","col1444","col1862"]                                                                              
int_best = train[a]

# %%
for i in int_best.columns:
    if len(int_best[i].unique()) != 2:
        print(i,len(int_best[i].unique()))
# Out:
# col88 275
# col3372 14
# col2414 19
# col2349 7
# col1725 11
# col1287 52
# col2410 65
# col142 67
# col1235 622
# col1232 58
# col1039 36
# col887 59
# col3640 263
# col2845 84
# col1459 125
# col286 57
# col1053 16
# col2565 7
# col1006 79
# col3535 35
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-dda05bd0bf62> in <module>()
#       1 for i in int_best.columns:
# ----> 2     if len(int_best[i].unique()) != 2:
#       3         print(i,len(int_best[i].unique()))
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# ...

# %%
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.feature_extraction.text import CountVectorizer
apps_of_ip = {}
for i,j in zip(train["col88"],train["col3372"]):
    apps_of_ip.setdefault(str(i), []).append(str(j))
ips = list(apps_of_ip.keys())
apps_as_sentence = [' '.join(apps_of_ip[ip]) for ip in ips]
apps_as_matrix = CountVectorizer().fit_transform(apps_as_sentence)
topics_of_ips = LDA(n_components=5).fit_transform(apps_as_matrix)

# %%
np.unique(topics_of_ips).shape
# Out:
# (21,)

# %%
tr = feather.read_dataframe("../data/input/tr_best.feather")
te = feather.read_dataframe("../data/input/te_best.feather")

# %%
tr_lda = feather.read_dataframe("../features/l_d_a_feature_train.feather")
te_lda = feather.read_dataframe("../features/l_d_a_feature_test.feather")

# %%
tr_ = df_concat([tr,tr_lda])
te_ = df_concat([te,te_lda])

# %%
tr_.reset_index(inplace = True)
te_.reset_index(inplace = True)
tr_.to_feather("../data/input/tr_best_lda.feather")
te_.to_feather("../data/input/te_best_lda.feather")
import json
del tr_["index"],tr_["Score"]
ff = tr_.columns.values.tolist()
features = {"features":ff, "target_name":"Score"}

with open("../configs/config_kbest_lda.json","w") as f:
    json.dump(features,f)

# %%
tr_pca = tr.loc[:,"PCA_1":]

# %%
te_pca= te.loc[:,"PCA_1":]

# %%
c = feather.read_dataframe("../features/add_cate.feather")
all_t = feather.read_dataframe("../features/add_Alltype.feather")

# %%
c_c = c.columns

# %%
np.random.seed(1103)
col = c_c[np.random.choice(np.arange(len(c_c)),size=100)]

# %%
c = c[col]

# %%
tr_c,te_c = c.iloc[:13731,:],c.iloc[13731:,:]

# %%
tr_a,te_a = all_t.iloc[:13731,:],all_t.iloc[13731:,:]

# %%
tr_= df_concat([tr_lda,tr_c,tr_a,tr_pca])
te_ = df_concat([te_lda,te_c,te_a,te_pca])

# %%
len(te_.columns.values)
# Out:
# 731

# %%
a =tr_.columns

# %%
for i in range(len(a)):
    for j in range(len(a)):
        if i != j and a[i] == a[j]:
            print(a[i])
# Out:
# col1883_col388_XOR
# col1918_count_enc
# col1944_col1458_XOR
# col1944_col1458_XOR
# col1918_count_enc
# col1883_col388_XOR

# %%
te_ = te_.loc[:,~te_.columns.duplicated()]

# %%
tr_
